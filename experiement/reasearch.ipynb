# %%
import pandas as pd

# %%
df=pd.read_csv("cubic_zirconia.csv")

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# 1      2.70    984
# 2      3.78   6289
# 3      2.96   1082
# 4      2.65    779
# ...     ...    ...
# 26962  4.09   5408
# 26963  2.74   1114
# 26964  3.17   1656
# 26965  2.60    682
# 26966  4.27   5166
#
# [26967 rows x 11 columns]

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 18542       18543   0.32      Ideal     G    VVS1   61.6   55.0  4.43  4.47
# 22179       22180   0.40  Very Good     F     VS1   61.2   58.0  4.74  4.86
# 3195         3196   1.54    Premium     G     SI2   61.6   58.0  7.45  7.30
# 3457         3458   0.68  Very Good     E     SI1   58.2   60.0  5.75  5.79
# 632           633   2.01    Premium     J     SI2   62.8   58.0  8.09  8.00
# 4427         4428   1.01    Premium     F     VS2   59.2   61.0  6.59  6.55
# 24972       24973   0.57       Good     G     VS2   58.2   66.0  5.34  5.45
# 17240       17241   1.29    Premium     E      I1   58.6   60.0  7.18  7.12
# 17301       17302   1.20    Premium     G     VS2   61.4   60.0  6.77  6.81
# 21589       21590   1.11  Very Good     H     SI2   59.8   60.0  6.66  6.75
#
#           z  price
# 18542  2.74    814
# 22179  2.94    847
# 3195   4.57   7287
# 3457   3.36   1918
# 632    5.05  12407
# 4427   3.89   6900
# 24972  3.14   1816
# 17240  4.19   3901
# 17301  4.17   7603
# 21589  4.01   4456

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.size
# Out:
# 296637

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x',
#        'y', 'z', 'price'],
#       dtype='object')

# %%
df.drop(labels=['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  object
#  2   color    26967 non-null  object
#  3   clarity  26967 non-null  object
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
cat_columns=df.columns[df.dtypes=='object']

# %%
num_columns=df.columns[df.dtypes!='object']

# %%
df[num_columns]
# Out:
#        carat  depth  table     x     y     z  price
# 0       0.30   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31   60.4   59.0  4.35  4.43  2.65    779
# ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 7 columns]

# %%
df[cat_columns].describe()
# Out:
#           cut  color clarity
# count   26967  26967   26967
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10816   5661    6571

# %%
for col in cat_columns:
     print(df[col].value_counts())
# Out:
# cut
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: count, dtype: int64
# color
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: count, dtype: int64
# clarity
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: count, dtype: int64

# %%
df[num_columns]
# Out:
#        carat  depth  table     x     y     z  price
# 0       0.30   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31   60.4   59.0  4.35  4.43  2.65    779
# ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 7 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
for col in num_columns:
     sns.histplot(data=df,x=col,kde=True)
     print("\n")

# %%
sns.heatmap(df[num_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
clarity_map={'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8}
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}

# %%
df['clarity']=df['clarity'].map(clarity_map)
df['cut']=df['cut'].map(cut_map)
df['color']=df['color'].map(color_map)

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 0       0.30    5      2        3   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    4      4        8   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90    3      2        6   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42    5      3        5   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31    5      3        7   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    4      4        3   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33    5      5        8   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    4      2        4   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27    3      3        6   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    4      7        3   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]
